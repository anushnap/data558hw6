# %% [markdown]
# ## <center> DATA 558 Homework 6 </center>
# <center> Anushna Prakash </center>
# <center> May 21, 2021 </center>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier

# %%
file = 'default_plus_chromatic_features_1059_tracks.txt'
dat = pd.read_csv(file, header = None)
X = dat.iloc[:,:-2]
y, orig = pd.factorize(dat.iloc[:,-1])

# %%
X
# Out:
#            0         1         2         3         4         5         6    \
# 0     7.161286  7.835325  2.911583  0.984049 -1.499546 -2.094097  0.576000
# 1     0.225763 -0.094169 -0.603646  0.497745  0.874036  0.290280 -0.077659
# 2    -0.692525 -0.517801 -0.788035  1.214351 -0.907214  0.880213  0.406899
# 3    -0.735562 -0.684055  2.058215  0.716328 -0.011393  0.805396  1.497982
# 4     0.570272  0.273157 -0.279214  0.083456  1.049331 -0.869295 -0.265858
# ...        ...       ...       ...       ...       ...       ...       ...
# 1054  0.399577  0.310805 -0.039326 -0.111546  0.304586 -0.943453  0.114960
# 1055  1.640386  1.306224  0.192745 -1.816855 -1.311906 -2.128963 -1.875967
# 1056 -0.772360 -0.670596 -0.840420 -0.832105  0.277346  1.152162  0.241470
# 1057 -0.996965 -1.099395  3.515274 -0.508185 -1.102654  0.192081  0.069821
# 1058 -0.150911 -0.094333 -0.568885 -0.614652  0.332477 -0.954948 -1.527722
#
# ...

# %%
type(y)
# Out:
# numpy.ndarray

# %%
# Split 80/20 train/test data and standardize X.
X_train_us, X_test_us, y_train, y_test = train_test_split(X.to_numpy(),
                                                    y,
                                                    test_size = 0.2,
                                                    random_state = 42)
X_ss = StandardScaler().fit(X_train_us)
X_train = X_ss.transform(X_train_us)
X_test = X_ss.transform(X_test_us)

# %% [markdown]
# Construct empirical covariance matrix $V_X = \frac{1}{n-1} X^T X$.

# %%
V = 1 / (X_train.shape[0] - 1) * X_train.T @ X_train
V.shape
# Out:
# (116, 116)

# %%
def poweriteralgo(Sigma, max_iter = 100):
    """
    Find the top principal component of the feature matrix.
    
    Inputs
    ---------
    Sigma : ndarray
        The square empirical covariance matrix
    max_iter : int
        The maximum number of iterations, default 100.
    
    Returns
    --------
    Something
    """
    pass
